# %% [markdown]
# <a href="https://colab.research.google.com/github/jenishcsimkhada/CSC101/blob/main/week8_my_data_story.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # My Data Story: Daily Routine Goals
# ## Week 8 - Files and Friends

# %%
# My Data Story
# Week 8 Assignment

filename = "my_data.txt"

# Open and read the file
with open(filename, "r", encoding="utf-8") as file:
    lines = file.readlines()

print("=== MY DATA STORY ===\n")

# Display the file contents
for line in lines:
    print(line.strip())

# Calculate statistics
print("\nTotal lines:", len(lines))

word_count = sum(len(line.split()) for line in lines)
print("Total words:", word_count)

print("\nFirst line:", lines[0].strip())
print("Last line:", lines[-1].strip())

longest_line = max(lines, key=len)
print("Longest line:", longest_line.strip())

# %% [markdown]
# ## AI Collaboration Log
#
# **My AI Prompt:**
# "Help me write Python code to read a text file, display its contents, and calculate statistics like the number of lines and words."
#
# **What the AI Helped Me With:**
# The AI helped me write the Python code to open and read a text file, display the contents clearly, and calculate statistics such as total lines, total words, first line, and last line. It also helped me fix file-name errors.
#
# **What I Learned:**
# I learned how Python reads text files and how to use simple functions to calculate useful information from the data.

# %% [markdown]
# ## My Reflection
#
# **What surprised me about working with files:**
# I was surprised that a very small mistake, like using the wrong file name, can stop the whole program from running.
#
# **How this connects to business:**
# This skill is useful in business because companies often work with files that store customer details, reports, or transaction records, and those files need to be read and analysed correctly.
#
# **Next thing I want to learn:**
# I want to learn how to create graphs and charts from data in Python.
