# %% [markdown]
# <a href="https://colab.research.google.com/github/jenishcsimkhada/CSC101/blob/main/ai_conversation_txt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 10 – AI Response File
#
#
# ## AI Prompts Used
#
# During this assignment, I used AI with specific prompts to help guide my understanding and verify my work. The prompts I used were:
#
# - “Explain the inputs and outputs for a tip calculator problem in simple terms.”
# - “Help me break down a late fee calculator with a $0.50 per day rule and a $10 maximum cap.”
# - “Check if my manual calculations for tip and total amount are correct.”
# - “Show me how to structure Step 1, Step 2, and Step 3 clearly in markdown format.”
#
# ## How AI Helped Me
#
# AI helped me understand how to break each problem into smaller steps. It guided me in identifying inputs, outputs, and the correct calculation process. It also helped confirm that my manual calculations were correct and logically structured.
#
#
# ## My Working Process
#
# I first read both problems carefully and attempted to solve them on my own. I calculated all values manually using basic arithmetic.
#
# After that, I used AI to check my understanding and verify whether my steps and answers were correct. I then refined my answers based on clarity and structure.
#
# All final answers were written in my own words.
#
#
# ## Reflection
#
# This task helped me improve my problem-solving skills by focusing on logic before coding. It also helped me understand how AI can be used as a support tool for learning rather than replacing thinking.
