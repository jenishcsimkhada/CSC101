# %% [markdown]
# <a href="https://colab.research.google.com/github/jenishcsimkhada/CSC101/blob/main/week_8_project_spec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e46a2c0f-d4d9-462c-8147-85870349d7f1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e46a2c0f-d4d9-462c-8147-85870349d7f1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Week 8: Smart Personal Finance Manager

def load_transactions(filename):
    """Read lines from a transaction file safely."""
    try:
        with open(filename, 'r') as file:
            lines = file.readlines()
        return [line.strip() for line in lines if line.strip()]
    except FileNotFoundError:
        print(f"File '{filename}' not found!")
        return []


def process_transactions(lines):
    """Process transaction lines into clean data."""
    transactions = []
    failed_count = 0

    for line in lines:
        try:
            # Try splitting line into description and amount
            description, amount_text = line.split(",")
            amount = float(amount_text)

            # Store as dictionary (as required)
            transactions.append({
                "description": description,
                "amount": amount
            })

        except ValueError:
            # Handle bad lines safely
            print(f"Skipping invalid line: {line}")
            failed_count += 1

    print(f"\nInvalid lines skipped: {failed_count}")
    return transactions


def show_summary(transactions):
    """Display results to the user."""
    total_income = 0
    total_expenses = 0

    for t in transactions:
        amount = t["amount"]
        if amount > 0:
            total_income += amount
        else:
            total_expenses += amount

    print("\nSummary:")
    print(f"Total Transactions: {len(transactions)}")
    print(f"Total Income: ${total_income}")
    print(f"Total Expenses: ${total_expenses}")
    print(f"Net Amount: ${total_income + total_expenses}")


# Main program
def main():
    print("🏦 Personal Finance Manager")
    print("=" * 30)

    # Load data
    filename = "transactions.txt"
    raw_lines = load_transactions(filename)

    if not raw_lines:
        print("No data to process!")
        return

    # Process data
    transactions = process_transactions(raw_lines)

    # Show results
    show_summary(transactions)


# Run the program
main()
# Out:
# 🏦 Personal Finance Manager
# ...
# Skipping invalid line: BAD LINE HERE
#
# Invalid lines skipped: 1
#
# Summary:
# Total Transactions: 6
# Total Income: $1535.5
# Total Expenses: $-155.89
# Net Amount: $1379.6100000000001

# %% [markdown]
# ## Reflection
#
# **What was the hardest part and how did AI help you solve it?**
#
# The hardest part was making sure the program did not crash when it encountered invalid or messy data, such as lines without commas or incorrect values. I initially found it difficult to handle these errors properly. I used AI to understand how to apply try-except blocks to safely skip bad lines while continuing the program. AI also helped me break the problem into smaller functions, such as loading data, processing transactions, and displaying results, which made the overall program easier to design and debug.
